# %% [markdown]
# ## Imports

# %%
import os
import re
import json
import jsonschema
import pandas as pd
import numpy as np
import logging
logging.basicConfig()
log = logging.getLogger('import_dicom_metadata')

# %% [markdown]
# ## Functions

# %%
def import_file(filepath):
    """
    This function determines the file data type and appropriately
    imports the file as a pandas object
    It also partially accounts for the bug where date
    parsing in pandas cannot be set to False for pd.read_excel()

    :param filepath: path to the excel file
    :type filepath: str
    :returns:  data_frame, a pandas dataframe without date
    """
    if filepath.endswith(('.xls', '.xlsx')):
        # read in dataframe from xls/xlsx
        dataframe = pd.read_excel(filepath)

        # if there are no datetimes series found, return  the
        if dataframe.select_dtypes('datetime64').empty:
            return dataframe
        # otherwise, convert to string and replace any NaT with NaN
        else:
            print('fixing datetime')
            # select the offending columns
            dtcolumns = dataframe.select_dtypes('datetime64').columns
            # loop over the columns
            for column in dtcolumns:
                # convert to string type
                dataframe[column] = dataframe[column].astype('str')
                # handle NaTs
                dataframe[column] = dataframe[column].replace('NaT', np.nan)
            return dataframe
    elif filepath.endswith('.csv'):
        dataframe = pd.read_csv(filepath)
        return dataframe
    else:
        print('File type is not supported')


def convert_value(value):
    """
    converts all objects to strings and handles trailing .0 on ints
    since pandas likes to spit out floats
    """
    if type(value) == str:
        return value
    else:
        # convert to string
        value = str(value)
        # clip trailing .0
        value = re.sub('\.0+$', '',value)
        return value


def export_to_dict(dataframe):
    """
    This function exports a pandas dataframe object
    to a dictionary

    :param dataframe: a pandas DataFrame object
    :type filepath: DataFrame
    :returns:  output_dic (dict) - the output object to be converted to json

    """
    # for now, assume subject is the first column
    subject_column = dataframe.columns[0]
    # get the count of the non-null subjects
    subject_count = dataframe[subject_column].count()
    # check that the above returned a value
    if type(subject_count) != np.int64:
        print("subject_count is not a valid integer. Dictionary not created.")
    # if there's only one subject, account for possibility of list columnns
    elif subject_count == 1:
        print("Processing single subject...")
        output_dict = {}
        for column in dataframe:
            if dataframe[column].count() > 1:
                output_dict[column] = dataframe[column].dropna().tolist()
            else:
                value = dataframe[column][0]
                #value = convert_value(value)
                output_dict[column] = value
        # output_json = json.dumps(output_dict)
        return output_dict
    elif subject_count < 1:
        print("No subjects in DataFrame. Dictionary not created.")
    else:
        print("Processing multiple subjects...")
        output_dict = {}
        dataframe = dataframe.astype("str")
        for index, row in dataframe.iterrows():
            key = row[subject_column]
            value = row.to_dict()
            output_dict[key] = value
        # output_json = json.dumps(output_dict)
        return output_dict

# %%
xls_filepath = "input.metadata.xlsx"
csv_filepath = "input.metadata.csv"
xls_dataframe = import_file(xls_filepath)
csv_dataframe = import_file(csv_filepath)
xls_dict = export_to_dict(xls_dataframe)
csv_dict = export_to_dict(csv_dataframe)
# Out:
# fixing datetime
# Processing single subject...
# Processing single subject...

# %%
template_filepath = "mr.metadata.template.json"

with open(template_filepath) as template_data:
    template_json = json.load(template_data)
JSON_template = {}
JSON_template['type'] = 'object'
JSON_template['properties'] = template_json

# %%
def match_template_strings(input_dict,template):
    """
    This is a funtion that converts numeric dictionary
    values to strings when specified by the template 
    to be used in validation and removes ".0" from floats
    
    """
    for key in input_dict:
        if key in template['properties']:
            if template['properties'][key]["type"] == ("string" or "str"):
                if type(input_dict[key]) != str:
                    input_dict[key] = convert_value(input_dict[key])
    return input_dict

# %%
match_template_strings(xls_dict,JSON_template)
# Out:
# DeviceSerialNumber
# PatientWeight
# ImageType
# SeriesNumber
# AcquisitionTime
# AcquisitionNumber
# SpacingBetweenSlices
# SAR
# FlipAngle
# PartialFourier
# BaseResolution
# ShimSetting
# TxRefAmp
# PhaseResolution
# MultibandAccelerationFactor
# PercentPhaseFOV
# EchoTrainLength
# PhaseEncodingSteps
# AcquisitionMatrixPE
# ReconMatrixPE
# BandwidthPerPixelPhaseEncode
# EffectiveEchoSpacing
# DerivedVendorReportedEchoSpacing
# TotalReadoutTime
# PixelBandwidth
# DwellTime
# SliceTiming
# ImageOrientationPatientDICOM
# {'Modality': 'MR',
#  'MagneticFieldStrength': 3.0,
#  'ImagingFrequency': 123.262,
#  'Manufacturer': 'Siemens',
#  'ManufacturersModelName': 'Prisma_fit',
#  'InstitutionName': 'BCBL',
#  'InstitutionalDepartmentName': 'Department',
#  'InstitutionAddress': 'Mikeletegi_69_San_Sebastian_District_ES_20009',
#  'DeviceSerialNumber': '167004',
#  'StationName': 'MRC35414',
#  'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0',
#  'StudyInstanceUID': '1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061',
#  'ReferringPhysicianName': 'Pedro',
#  'StudyID': 1.0,
#  'PatientName': '14_MAGNO_7806',
#  'PatientID': 'MAGNO',
#  'PatientBirthDate': '1995-10-10',
#  'PatientSex': 'M',
#  'PatientWeight': '80',
#  'BodyPartExamined': 'BRAIN',
#  'PatientPosition': 'HFS',
#  'ProcedureStepDescription': 'CRANEO_FUNCIONAL',
#  'SoftwareVersions': 'syngo_MR_E11',
#  'MRAcquisitionType': '2D',
#  'SeriesDescription': 'RetinotopicAtlas_Run1',
#  'ProtocolName': 'RetinotopicAtlas_Run1',
#  'ScanningSequence': 'EP',
#  'SequenceVariant': 'SK_SS',
#  'ScanOptions': 'PFP_FS',
#  'SequenceName': 'epfid2d1_96',
#  'ImageType': "['ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSAIC']",
#  'SeriesNumber': '62',
#  'AcquisitionTime': '18:31:20.840000',
#  'AcquisitionDateTime': '2019-03-03 18:31:20.840',
#  'AcquisitionNumber': '1',
#  'ImageComments': 'Unaliased_MB3_PE3_LB_SENSE1',
#  'SliceThickness': 2.0,
#  'SpacingBetweenSlices': '2',
#  'SAR': '0.0593594',
#  'EchoTime': 0.0308,
#  'RepetitionTime': 1.82,
#  'FlipAngle': '75',
#  'PartialFourier': '0.875',
#  'BaseResolution': '96',
#  'ShimSetting': '[76.0, -11164.0, -7059.0, 545.0, 24.0, -195.0, -86.0, 15.0]',
#  'TxRefAmp': '246.591',
#  'PhaseResolution': '1',
#  'ReceiveCoilName': 'HeadNeck_64',
#  'ReceiveCoilActiveElements': 'HC1-7;NC1,2',
#  'CoilString': 'HC1-7;NC1_2',
#  'PulseSequenceDetails': '%CustomerSeq%_cmrr_mbep2d_bold',
#  'WipMemBlock': '2b0a4368-108d-4a1e-8404-12d445946a00||Sequence: R016 ve11c/master r/8780670; Nov 27 2017 15:05:12 by eja',
#  'ConsistencyInfo': 'N4_VE11C_LATEST_20160120',
#  'MultibandAccelerationFactor': '3',
#  'PercentPhaseFOV': '100',
#  'EchoTrainLength': '84',
#  'PhaseEncodingSteps': '84',
#  'AcquisitionMatrixPE': '96',
#  'ReconMatrixPE': '96',
#  'BandwidthPerPixelPhaseEncode': '17.96',
#  'EffectiveEchoSpacing': '0.000579993',
#  'DerivedVendorReportedEchoSpacing': '0.000579993',
#  'TotalReadoutTime': '0.0550993',
#  'PixelBandwidth': '2365',
#  'DwellTime': '2.2e-06',
#  'PhaseEncodingDirection': 'j-',
#  'SliceTiming': '[0.0, 0.825, 1.65, 0.675, 1.5, 0.525, 1.35, 0.375, 1.2, 0.225, 1.05, 0.075, 0.9, 1.725, 0.75, 1.575, 0.6, 1.425, 0.45, 1.275, 0.3, 1.125, 0.15, 0.975, 0.0, 0.825, 1.65, 0.675, 1.5, 0.525, 1.35, 0.375, 1.2, 0.225, 1.05, 0.075, 0.9, 1.725, 0.75, 1.575, 0.6, 1.425, 0.45, 1.275, 0.3, 1.125, 0.15, 0.975, 0.0, 0.825, 1.65, 0.675, 1.5, 0.525, 1.35, 0.375, 1.2, 0.225, 1.05, 0.075, 0.9, 1.725, 0.75, 1.575, 0.6, 1.425, 0.45, 1.275, 0.3, 1.125, 0.15, 0.975]',
#  'ImageOrientationPatientDICOM': '[0.999369, -0.0247382, -0.0254766, 0.0237259, 0.998946, -0.0392976]',
#  'InPlanePhaseEncodingDirectionDICOM': 'COL',
#  'ConversionSoftware': 'dcm2niix',
#  'ConversionSoftwareVersion': 'v1.0.20181114  (JP2:OpenJPEG) GCC4.8.4'}

# %%
type(xls_dict['StudyInstanceUID'])
# Out:
# str

# %%
required_array = []
for key in JSON_template['properties']:
    try:
        if JSON_template['properties'][key]['required'] is True:
            print(key)
            required_array.append(key)
            JSON_template['properties'][key].pop('required', None)
    except KeyError:
        continue
# Out:
# Modality
# MagneticFieldStrength
# SeriesInstanceUID
# StudyInstanceUID
# StudyID
# PatientID
# BodyPartExamined
# MRAcquisitionType
# SeriesDescription
# ScanningSequence
# SliceThickness
# EchoTime
# RepetitionTime
# ClinicalTrialTimePointID
# ClinicalTrialTimePointDescription
# PixelSpacing
# InversionTime

# %%
JSON_template['required'] = required_array

# %%
def validate_against_template(input_dict,template,error_log_path):
    # Initialize json schema validator
    validator = jsonschema.Draft7Validator(template)
    # Initialize list object for storing validation errors
    validation_errors = []
    for error in sorted(validator.iter_errors(input_dict), key=str):
        # Create a temporary dictionary for the individual error
        tmp_dict = {} 
        # Get error type
        tmp_dict['error_type'] = error.validator
        # Get error message and log it
        tmp_dict['error_message'] = error.message
        log.error(error.message)
        # Required field errors are a little special and need to be handled
        ## separately to get the field. We don't get the schema because it
        ## will print the entire template schema
        if error.validator == "required":
            # Get the item failing validation from the error message
            tmp_dict['item'] = 'info.' + error.message.split("'")[1]
        else:
            # Get the value of the field that failed validation
            tmp_dict['error_value'] = error.instance
            # Get the field that failed validation
            tmp_dict['item'] = 'info.' + str(error.path.pop())
            # Get the schema object used to validate in failed validation
            tmp_dict['schema'] = error.schema
        # Append individual error object to the return validation_errors object
        validation_errors.append(tmp_dict)

    with open(error_log_path, 'w') as outfile:
        json.dump(validation_errors, outfile, separators=(', ', ': '), sort_keys=True, indent=4)
    return validation_errors

# %%
validation_errors
# Out:
# [{'error_type': 'pattern',
#   'error_message': "'1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0' does not match '/^\\\\d{1}\\\\.\\\\d{1}(\\\\.\\\\d{1,55})?$/'",
#   'error_value': '1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0',
#   'item': 'info.SeriesInstanceUID',
#   'schema': {'type': 'string',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'required': True,
#    'description': 'SeriesInstanceUID must match above pattern. Example. 1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0'}},
#  {'error_type': 'pattern',
#   'error_message': "'1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061' does not match '/^\\\\d{1}\\\\.\\\\d{1}(\\\\.\\\\d{1,55})?$/'",
#   'error_value': '1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061',
#   'item': 'info.StudyInstanceUID',
#   'schema': {'type': 'string',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'required': True,
#    'description': 'StudyInstanceUID is an optional field. Example. 1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061'}},
#  {'error_type': 'pattern',
#   'error_message': '\'2D\' does not match \'/[A-Za-z0-9-_.,!"\\\'/$]*/\'',
#   'error_value': '2D',
#   'item': 'info.MRAcquisitionType',
#   'schema': {'type': 'string',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'required': True,
#    'description': 'MRAcquisitionType could be any string, /[A-Za-z0-9-_.,!"\'/$]*/". Example. 2D, 3D_GRASE'}},
#  {'error_type': 'pattern',
#   'error_message': "'BRAIN' does not match '/^[A-Za-z]{1,}/'",
#   'error_value': 'BRAIN',
#   'item': 'info.BodyPartExamined',
#   'schema': {'type': 'string',
#    'pattern': '/^[A-Za-z]{1,}/',
#    'required': True,
#    'description': 'BodyPartExamined must match /^[A-Za-z]{1+}/. Example. BRAIN'}},
#  {'error_type': 'pattern',
#   'error_message': '\'EP\' does not match \'/[A-Za-z0-9-_.,!"\\\'/$]*/\'',
#   'error_value': 'EP',
#   'item': 'info.ScanningSequence',
#   'schema': {'type': 'string',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'required': True,
#    'description': 'ScanningSequence is required and can be any string. Example. EPI'}},
#  {'error_type': 'pattern',
#   'error_message': "'MAGNO' does not match '/^[A-Za-z0-9]{1+}/'",
#   'error_value': 'MAGNO',
#   'item': 'info.PatientID',
#   'schema': {'type': 'string',
#    'pattern': '/^[A-Za-z0-9]{1+}/',
#    'required': True,
#    'description': 'PatientID must match ^[A-Za-z0-9]{1+}/. Example. S001'}},
#  {'error_type': 'pattern',
#   'error_message': "'MR' does not match '/MR/'",
#   'error_value': 'MR',
#   'item': 'info.Modality',
#   'schema': {'type': 'string',
#    'pattern': '/MR/',
#    'required': True,
#    'description': "Modality must match 'MR'"}},
#  {'error_type': 'pattern',
#   'error_message': "'RetinotopicAtlas_Run1' does not match '/^[A-Za-z_\\\\-0-9]{1,}'",
#   'error_value': 'RetinotopicAtlas_Run1',
#   'item': 'info.SeriesDescription',
#   'schema': {'type': 'string',
#    'pattern': '/^[A-Za-z_\\-0-9]{1,}',
#    'required': True,
#    'description': 'SeriesDescription must match /^[A-Za-z]{1+}/. Example. RetinotopicAtlas_Run1, fmri-head'}}]

# %%
JSON_template
# Out:
# {'type': 'object',
#  'properties': {'Modality': {'type': 'string',
#    'pattern': '/MR/',
#    'description': "Modality must match 'MR'"},
#   'MagneticFieldStrength': {'type': 'number',
#    'pattern': '/^\\d{0,2}(\\.\\d{1})?$/',
#    'description': 'MagneticFieldStrength must match /^\\d{0,2}(\\.\\d{1})?$/. Example: 3, 3.0 or 11.7'},
#   'ImagingFrequency': {'type': 'number',
#    'description': 'ImagingFrequency is an optional field. If proivded it must be a number. Example. 123.262'},
#   'Manufacturer': {'type': 'string',
#    'description': 'Manufacturer is an optional field. Example. Siemens'},
#   'ManufacturersModelName': {'type': 'string',
#    'description': 'ManufacturersModelName is an optional field. Example. Prisma_fit'},
#   'InstitutionName': {'type': 'string',
#    'description': 'InstitutionName is an optional field. Example. Stanford University'},
#   'InstitutionalDepartmentName': {'type': 'string',
#    'description': 'InstitutionalDepartmentName is an optional field. Example. Psychiatary'},
#   'InstitutionAddress': {'type': 'string',
#    'description': 'InstitutionAddress is an optional field. Example. 1234 Main St. City, CA 12345'},
#   'DeviceSerialNumber': {'type': 'string',
#    'description': 'DeviceSerialNumber is an optional field. Example. 123456789'},
#   'StationName': {'type': 'string',
#    'description': 'StationName is an optional field. Example. MRC35414'},
#   'SeriesInstanceUID': {'type': 'string',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'description': 'SeriesInstanceUID must match above pattern. Example. 1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0'},
#   'StudyInstanceUID': {'type': 'string',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'description': 'StudyInstanceUID is an optional field. Example. 1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061'},
#   'ReferringPhysicianName': {'type': 'string',
#    'description': 'ReferringPhysicianName is an optional field. Example. Dr. Smith'},
#   'StudyID': {'type': 'number',
#    'pattern': '/^\\d{1,}/',
#    'description': 'StudyID must match /^[0-9]{1+}/. Example. 1'},
#   'PatientName': {'type': 'string',
#    'description': 'PatientName is an optional field. Example. John Doe'},
#   'PatientID': {'type': 'string',
#    'pattern': '/^[A-Za-z0-9]{1+}/',
#    'description': 'PatientID must match ^[A-Za-z0-9]{1+}/. Example. S001'},
#   'PatientSex': {'type': 'string',
#    'description': 'PatientSex is an optional field. Example. Male'},
#   'PatientWeight': {'type': 'string',
#    'description': 'PatientWeight is an optional field. Example. 80'},
#   'BodyPartExamined': {'type': 'string',
#    'pattern': '/^[A-Za-z]{1,}/',
#    'description': 'BodyPartExamined must match /^[A-Za-z]{1+}/. Example. BRAIN'},
#   'PatientPosition': {'type': 'string',
#    'description': 'PatientPosition is an optional field. Example. HFS'},
#   'ProcedureStepDescription': {'type': 'string',
#    'description': 'ProcedureStepDescription is an optional field. Example. CRANEO_FUNCIONAL'},
#   'SoftwareVersions': {'type': 'string',
#    'description': 'SoftwareVersions is an optional field. Example. Syngo_MR_E11'},
#   'MRAcquisitionType': {'type': 'string',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'description': 'MRAcquisitionType could be any string, /[A-Za-z0-9-_.,!"\'/$]*/". Example. 2D, 3D_GRASE'},
#   'SeriesDescription': {'type': 'string',
#    'pattern': '/^[A-Za-z_\\-0-9]{1,}',
#    'description': 'SeriesDescription must match /^[A-Za-z]{1+}/. Example. RetinotopicAtlas_Run1, fmri-head'},
#   'ProtocolName': {'type': 'string',
#    'description': 'ProtocolName is an optional field. Example. RetinotopicAtlas_Run1'},
#   'ScanningSequence': {'type': 'string',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'description': 'ScanningSequence is required and can be any string. Example. EPI'},
#   'SequenceVariant': {'type': 'string',
#    'description': 'SequenceVariant is an optional field. Example. SK_SS'},
#   'ScanOptions': {'type': 'string',
#    'description': 'ScanOptions is an optional field. Example. PFP_FS'},
#   'SequenceName': {'type': 'string',
#    'description': 'SequenceName is an optional field. Example. epfid2d1_96'},
#   'ImageType': {'type': 'string',
#    'description': 'ImageType is an optional field. Example. Mosaic'},
#   'SeriesNumber': {'type': 'string',
#    'description': 'SeriesNumber is an optional field. Example. 62'},
#   'AcquisitionTime': {'type': 'string',
#    'description': 'AcquisitionTime is an optional field. Example. 18:31:21'},
#   'AcquisitionDateTime': {'type': 'string',
#    'description': 'AcquisitionDateTime is an optional field. Example. 3/3/2019  6:31:21 PM'},
#   'AcquisitionNumber': {'type': 'string',
#    'description': 'AcquisitionNumber is an optional field. Example. 1'},
#   'ImageComments': {'type': 'string',
#    'description': 'ImageComments is an optional field. Example. Unaliased_MB3_PE3_LB_SENSE1'},
#   'SliceThickness': {'type': 'number',
#    'pattern': '/^\\d{0,2}(\\.\\d{1,})?$/',
#    'description': 'SliceThickness must match /^\\d{0,2}(\\.\\d{1,})?$/. Example: 2 or 2.5433'},
#   'SpacingBetweenSlices': {'type': 'string',
#    'description': 'SpacingBetweenSlices is an optional field. Example. 1'},
#   'SAR': {'type': 'string',
#    'description': 'SAR is an optional field. Example. 0.0593594'},
#   'EchoTime': {'type': 'number',
#    'pattern': '/^\\d{0,4}(\\.\\d{1,})?$/',
#    'description': 'InversionTime must match /^\\d{0,4}(\\.\\d{1,})?$/. Example: 75 or 34.2'},
#   'RepetitionTime': {'type': 'number',
#    'pattern': '/^\\d{0,4}(\\.\\d{1,})?$/',
#    'description': 'RepetitionTime must match /^\\d{0,4}(\\.\\d{1,})?$/. Example: 4 or 4.2'},
#   'FlipAngle': {'type': 'string',
#    'description': 'FlipAngle is an optional field. Example. 75'},
#   'PartialFourier': {'type': 'string',
#    'description': 'PartialFourier is an optional field. Example. 0.875'},
#   'BaseResolution': {'type': 'string',
#    'description': 'BaseResolution is an optional field. Example. 96'},
#   'ShimSetting': {'type': 'string',
#    'description': 'ShimSetting is an optional field. Example. 76,-11164,-7059,545,24,-195,-86,15'},
#   'TxRefAmp': {'type': 'string',
#    'description': 'TxRefAmp is an optional field. Example. 246.591'},
#   'PhaseResolution': {'type': 'string',
#    'description': 'PhaseResolution is an optional field. Example. 1'},
#   'ReceiveCoilName': {'type': 'string',
#    'description': 'ReceiveCoilName is an optional field. Example. HeadNeck_64'},
#   'ReceiveCoilActiveElements': {'type': 'string',
#    'description': 'ReceiveCoilActiveElements is an optional field. Example. HC1-7;NC1,2'},
#   'CoilString': {'type': 'string',
#    'description': 'CoilString is an optional field. Example. HC1-7;NC1_2'},
#   'PulseSequenceDetails': {'type': 'string',
#    'description': 'PulseSequenceDetails is an optional field. Example. mbep2d_bold'},
#   'WipMemBlock': {'type': 'string',
#    'description': 'WipMemBlock is an optional field. Example. 2b0a4368-108d-4a1e-8404-12d445946a00'},
#   'ConsistencyInfo': {'type': 'string',
#    'description': 'ConsistencyInfo is an optional field. Example. N4_VE11C_LATEST_20160120'},
#   'MultibandAccelerationFactor': {'type': 'string',
#    'description': 'MultibandAccelerationFactor is an optional field. Example. 3'},
#   'PercentPhaseFOV': {'type': 'string',
#    'description': 'PercentPhaseFOV is an optional field. Example. 100'},
#   'EchoTrainLength': {'type': 'string',
#    'description': 'EchoTrainLength is an optional field. Example. 84'},
#   'PhaseEncodingSteps': {'type': 'string',
#    'description': 'PhaseEncodingSteps is an optional field. Example. 84'},
#   'AcquisitionMatrixPE': {'type': 'string',
#    'description': 'AcquisitionMatrixPE is an optional field. Example. 96'},
#   'ReconMatrixPE': {'type': 'string',
#    'description': 'ReconMatrixPE is an optional field. Example. 96'},
#   'BandwidthPerPixelPhaseEncode': {'type': 'string',
#    'description': 'BandwidthPerPixelPhaseEncode is an optional field. Example. 17.96'},
#   'EffectiveEchoSpacing': {'type': 'string',
#    'description': 'EffectiveEchoSpacing is an optional field. Example. 0.000579993'},
#   'DerivedVendorReportedEchoSpacing': {'type': 'string',
#    'description': 'DerivedVendorReportedEchoSpacing is an optional field. Example. 0.000579993'},
#   'TotalReadoutTime': {'type': 'string',
#    'description': 'TotalReadoutTime is an optional field. Example. 0.0550993'},
#   'PixelBandwidth': {'type': 'string',
#    'description': 'PixelBandwidth is an optional field. Example. 2365'},
#   'DwellTime': {'type': 'string',
#    'description': 'DwellTime is an optional field. Example. 0.0000022'},
#   'PhaseEncodingDirection': {'type': 'string',
#    'description': 'PhaseEncodingDirection is an optional field. Example. j-'},
#   'SliceTiming': {'type': 'string',
#    'description': 'SliceTiming is an optional field. Example. 0,0.825,1.65,1.5,0.525'},
#   'ImageOrientationPatientDICOM': {'type': 'string',
#    'description': 'ImageOrientationPatientDICOM is an optional field. Example. 0.999369,-0.0247382,-0.0254766'},
#   'InPlanePhaseEncodingDirectionDICOM': {'type': 'string',
#    'description': 'InPlanePhaseEncodingDirectionDICOM is an optional field. Example. COL'},
#   'ConversionSoftware': {'type': 'string',
#    'description': 'ConversionSoftware is an optional field. Example. dcm2niix'},
#   'ConversionSoftwareVersion': {'type': 'string',
#    'description': 'ConversionSoftwareVersion is an optional field. Example. v1.0.20181114  (JP2:OpenJPEG) GCC4.8.4'},
#   'ClinicalTrialTimePointID': {'type': 'string',
#    'pattern': '/^\\d{1,}(\\.\\d{1,})+?$/',
#    'description': 'ClinicalTrialTimePointID is an optional field. Example. 11.1.2014'},
#   'ClinicalTrialTimePointDescription': {'type': 'string',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'description': 'ClinicalTrialTimePointDescription is required and can be any string. Example. This is clinical trial is for drug Rx'},
#   'PixelSpacing': {'type': 'number',
#    'pattern': '/^\\d{0,2}(\\.\\d{1,})?$/',
#    'description': 'PixelSpacing must match /^\\d{0,2}(\\.\\d{1,})?$/. Example: 2 or 2.5433'},
#   'InversionTime': {'type': 'number',
#    'pattern': '/^\\d{0,4}(\\.\\d{1,})?$/',
#    'description': 'InversionTime must match /^\\d{0,4}(\\.\\d{1,})?$/. Example: 2 or 2.5433'}},
#  'required': ['Modality',
#   'MagneticFieldStrength',
#   'SeriesInstanceUID',
#   'StudyInstanceUID',
#   'StudyID',
#   'PatientID',
#   'BodyPartExamined',
#   'MRAcquisitionType',
#   'SeriesDescription',
#   'ScanningSequence',
#   'SliceThickness',
#   'EchoTime',
#   'RepetitionTime',
#   'ClinicalTrialTimePointID',
#   'ClinicalTrialTimePointDescription',
#   'PixelSpacing',
#   'InversionTime']}

# %%
with open("revised.mr.metadata.template.json", 'w') as outfile:
    json.dump(JSON_template, outfile, separators=(', ', ': '), sort_keys=True, indent=4)
    template_filepath = "mr.metadata.template.json"

# %%
template_filepath = 'revised.mr.metadata.template.json'
with open(template_filepath) as template_data:
    template_json2 = json.load(template_data)

# %%
validate_against_template(xls_dict,template_json2,"test.error.log.json")
# Out:
# ERROR:import_dicom_metadata:'1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0' does not match '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/'
# ERROR:import_dicom_metadata:'1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061' does not match '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/'
# ERROR:import_dicom_metadata:'2D' does not match '/[A-Za-z0-9-_.,!"\'/$]*/'
# ERROR:import_dicom_metadata:'BRAIN' does not match '/^[A-Za-z]{1,}/'
# ERROR:import_dicom_metadata:'ClinicalTrialTimePointDescription' is a required property
# ERROR:import_dicom_metadata:'ClinicalTrialTimePointID' is a required property
# ERROR:import_dicom_metadata:'EP' does not match '/[A-Za-z0-9-_.,!"\'/$]*/'
# ERROR:import_dicom_metadata:'InversionTime' is a required property
# ERROR:import_dicom_metadata:'MAGNO' does not match '/^[A-Za-z0-9]{1+}/'
# ERROR:import_dicom_metadata:'MR' does not match '/MR/'
# ERROR:import_dicom_metadata:'PixelSpacing' is a required property
# ERROR:import_dicom_metadata:'RetinotopicAtlas_Run1' does not match '/^[A-Za-z_\\-0-9]{1,}'
# [{'error_type': 'pattern',
#   'error_message': "'1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0' does not match '/^\\\\d{1}\\\\.\\\\d{1}(\\\\.\\\\d{1,55})?$/'",
#   'error_value': '1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0',
#   'item': 'info.SeriesInstanceUID',
#   'schema': {'description': 'SeriesInstanceUID must match above pattern. Example. 1.3.12.2.1107.5.2.43.167004.2019030318311045850440175.0.0.0',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'type': 'string'}},
#  {'error_type': 'pattern',
#   'error_message': "'1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061' does not match '/^\\\\d{1}\\\\.\\\\d{1}(\\\\.\\\\d{1,55})?$/'",
#   'error_value': '1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061',
#   'item': 'info.StudyInstanceUID',
#   'schema': {'description': 'StudyInstanceUID is an optional field. Example. 1.3.12.2.1107.5.2.43.167004.30000019022812230075700000061',
#    'pattern': '/^\\d{1}\\.\\d{1}(\\.\\d{1,55})?$/',
#    'type': 'string'}},
#  {'error_type': 'pattern',
#   'error_message': '\'2D\' does not match \'/[A-Za-z0-9-_.,!"\\\'/$]*/\'',
#   'error_value': '2D',
#   'item': 'info.MRAcquisitionType',
#   'schema': {'description': 'MRAcquisitionType could be any string, /[A-Za-z0-9-_.,!"\'/$]*/". Example. 2D, 3D_GRASE',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'type': 'string'}},
#  {'error_type': 'pattern',
#   'error_message': "'BRAIN' does not match '/^[A-Za-z]{1,}/'",
#   'error_value': 'BRAIN',
#   'item': 'info.BodyPartExamined',
#   'schema': {'description': 'BodyPartExamined must match /^[A-Za-z]{1+}/. Example. BRAIN',
#    'pattern': '/^[A-Za-z]{1,}/',
#    'type': 'string'}},
#  {'error_type': 'required',
#   'error_message': "'ClinicalTrialTimePointDescription' is a required property",
#   'item': 'info.ClinicalTrialTimePointDescription'},
#  {'error_type': 'required',
#   'error_message': "'ClinicalTrialTimePointID' is a required property",
#   'item': 'info.ClinicalTrialTimePointID'},
#  {'error_type': 'pattern',
#   'error_message': '\'EP\' does not match \'/[A-Za-z0-9-_.,!"\\\'/$]*/\'',
#   'error_value': 'EP',
#   'item': 'info.ScanningSequence',
#   'schema': {'description': 'ScanningSequence is required and can be any string. Example. EPI',
#    'pattern': '/[A-Za-z0-9-_.,!"\'/$]*/',
#    'type': 'string'}},
#  {'error_type': 'required',
#   'error_message': "'InversionTime' is a required property",
#   'item': 'info.InversionTime'},
#  {'error_type': 'pattern',
#   'error_message': "'MAGNO' does not match '/^[A-Za-z0-9]{1+}/'",
#   'error_value': 'MAGNO',
#   'item': 'info.PatientID',
#   'schema': {'description': 'PatientID must match ^[A-Za-z0-9]{1+}/. Example. S001',
#    'pattern': '/^[A-Za-z0-9]{1+}/',
#    'type': 'string'}},
#  {'error_type': 'pattern',
#   'error_message': "'MR' does not match '/MR/'",
#   'error_value': 'MR',
#   'item': 'info.Modality',
#   'schema': {'description': "Modality must match 'MR'",
#    'pattern': '/MR/',
#    'type': 'string'}},
#  {'error_type': 'required',
#   'error_message': "'PixelSpacing' is a required property",
#   'item': 'info.PixelSpacing'},
#  {'error_type': 'pattern',
#   'error_message': "'RetinotopicAtlas_Run1' does not match '/^[A-Za-z_\\\\-0-9]{1,}'",
#   'error_value': 'RetinotopicAtlas_Run1',
#   'item': 'info.SeriesDescription',
#   'schema': {'description': 'SeriesDescription must match /^[A-Za-z]{1+}/. Example. RetinotopicAtlas_Run1, fmri-head',
#    'pattern': '/^[A-Za-z_\\-0-9]{1,}',
#    'type': 'string'}}]
